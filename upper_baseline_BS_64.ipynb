# %% [markdown]
# #### import libraries

# %%
from src import get_dataloader
from src.utils import show_batch
from src.utils import plot_training_stats
from src.neural_network import custom_resnet18
from src.solver import solver
from matplotlib import pyplot as plt
import numpy as np
import torch

# %% [markdown]
# #### get dataloaders

# %%
train_loader, val_loader, test_loader = get_dataloader.main(
    DATA_DIR = "./data/256_ObjectCategories",
    TEST_RATIO = 0.1,
    VAL_RATIO = 0.1,
    RS = 42, # Random seed
    BS = 64, # Batch size
    TOTAL_MEANS = [0.485, 0.456, 0.406], # use [0.5520134568214417, 0.533597469329834, 0.5050241947174072], # for custom total means per RGB-channel
    TOTAL_STDS = [0.229, 0.224, 0.225], # use [0.03332509845495224, 0.03334072232246399, 0.0340290367603302], # total stds per RGB-channel
    RANDOM_AFFINE = 5,
    RESIZE = (224, 224),
    RANDOM_CROP = (160, 160)
)

# %%
train_loader.dataset.classes
# Out:
# ['001.ak47',
#  '002.american-flag',
#  '003.backpack',
#  '004.baseball-bat',
#  '005.baseball-glove',
#  '006.basketball-hoop',
#  '007.bat',
#  '008.bathtub',
#  '009.bear',
#  '010.beer-mug',
#  '011.billiards',
#  '012.binoculars',
#  '013.birdbath',
#  '014.blimp',
#  '015.bonsai-101',
#  '016.boom-box',
#  '017.bowling-ball',
#  '018.bowling-pin',
#  '019.boxing-glove',
#  '020.brain-101',
#  '021.breadmaker',
#  '022.buddha-101',
#  '023.bulldozer',
#  '024.butterfly',
#  '025.cactus',
#  '026.cake',
#  '027.calculator',
#  '028.camel',
#  '029.cannon',
#  '030.canoe',
#  '031.car-tire',
#  '032.cartman',
#  '033.cd',
#  '034.centipede',
#  '035.cereal-box',
#  '036.chandelier-101',
#  '037.chess-board',
#  '038.chimp',
#  '039.chopsticks',
#  '040.cockroach',
#  '041.coffee-mug',
#  '042.coffin',
#  '043.coin',
#  '044.comet',
#  '045.computer-keyboard',
#  '046.computer-monitor',
#  '047.computer-mouse',
#  '048.conch',
#  '049.cormorant',
#  '050.covered-wagon',
#  '051.cowboy-hat',
#  '052.crab-101',
#  '053.desk-globe',
#  '054.diamond-ring',
#  '055.dice',
#  '056.dog',
#  '057.dolphin-101',
#  '058.doorknob',
#  '059.drinking-straw',
#  '060.duck',
#  '061.dumb-bell',
#  '062.eiffel-tower',
#  '063.electric-guitar-101',
#  '064.elephant-101',
#  '065.elk',
#  '066.ewer-101',
#  '067.eyeglasses',
#  '068.fern',
#  '069.fighter-jet',
#  '070.fire-extinguisher',
#  '071.fire-hydrant',
#  '072.fire-truck',
#  '073.fireworks',
#  '074.flashlight',
#  '075.floppy-disk',
#  '076.football-helmet',
#  '077.french-horn',
#  '078.fried-egg',
#  '079.frisbee',
#  '080.frog',
#  '081.frying-pan',
#  '082.galaxy',
#  '083.gas-pump',
#  '084.giraffe',
#  '085.goat',
#  '086.golden-gate-bridge',
#  '087.goldfish',
#  '088.golf-ball',
#  '089.goose',
#  '090.gorilla',
#  '091.grand-piano-101',
#  '092.grapes',
#  '093.grasshopper',
#  '094.guitar-pick',
#  '095.hamburger',
#  '096.hammock',
#  '097.harmonica',
#  '098.harp',
#  '099.harpsichord',
#  '100.hawksbill-101',
#  '101.head-phones',
#  '102.helicopter-101',
#  '103.hibiscus',
#  '104.homer-simpson',
#  '105.horse',
#  '106.horseshoe-crab',
#  '107.hot-air-balloon',
#  '108.hot-dog',
#  '109.hot-tub',
#  '110.hourglass',
#  '111.house-fly',
#  '112.human-skeleton',
#  '113.hummingbird',
#  '114.ibis-101',
#  '115.ice-cream-cone',
#  '116.iguana',
#  '117.ipod',
#  '118.iris',
#  '119.jesus-christ',
#  '120.joy-stick',
#  '121.kangaroo-101',
#  '122.kayak',
#  '123.ketch-101',
#  '124.killer-whale',
#  '125.knife',
#  '126.ladder',
#  '127.laptop-101',
#  '128.lathe',
#  '129.leopards-101',
#  '130.license-plate',
#  '131.lightbulb',
#  '132.light-house',
#  '133.lightning',
#  '134.llama-101',
#  '135.mailbox',
#  '136.mandolin',
#  '137.mars',
#  '138.mattress',
#  '139.megaphone',
#  '140.menorah-101',
#  '141.microscope',
#  '142.microwave',
#  '143.minaret',
#  '144.minotaur',
#  '145.motorbikes-101',
#  '146.mountain-bike',
#  '147.mushroom',
#  '148.mussels',
#  '149.necktie',
#  '150.octopus',
#  '151.ostrich',
#  '152.owl',
#  '153.palm-pilot',
#  '154.palm-tree',
#  '155.paperclip',
#  '156.paper-shredder',
#  '157.pci-card',
#  '158.penguin',
#  '159.people',
#  '160.pez-dispenser',
#  '161.photocopier',
#  '162.picnic-table',
#  '163.playing-card',
#  '164.porcupine',
#  '165.pram',
#  '166.praying-mantis',
#  '167.pyramid',
#  '168.raccoon',
#  '169.radio-telescope',
#  '170.rainbow',
#  '171.refrigerator',
#  '172.revolver-101',
#  '173.rifle',
#  '174.rotary-phone',
#  '175.roulette-wheel',
#  '176.saddle',
#  '177.saturn',
#  '178.school-bus',
#  '179.scorpion-101',
#  '180.screwdriver',
#  '181.segway',
#  '182.self-propelled-lawn-mower',
#  '183.sextant',
#  '184.sheet-music',
#  '185.skateboard',
#  '186.skunk',
#  '187.skyscraper',
#  '188.smokestack',
#  '189.snail',
#  '190.snake',
#  '191.sneaker',
#  '192.snowmobile',
#  '193.soccer-ball',
#  '194.socks',
#  '195.soda-can',
#  '196.spaghetti',
#  '197.speed-boat',
#  '198.spider',
#  '199.spoon',
#  '200.stained-glass',
#  '201.starfish-101',
#  '202.steering-wheel',
#  '203.stirrups',
#  '204.sunflower-101',
#  '205.superman',
#  '206.sushi',
#  '207.swan',
#  '208.swiss-army-knife',
#  '209.sword',
#  '210.syringe',
#  '211.tambourine',
#  '212.teapot',
#  '213.teddy-bear',
#  '214.teepee',
#  '215.telephone-box',
#  '216.tennis-ball',
#  '217.tennis-court',
#  '218.tennis-racket',
#  '219.theodolite',
#  '220.toaster',
#  '221.tomato',
#  '222.tombstone',
#  '223.top-hat',
#  '224.touring-bike',
#  '225.tower-pisa',
#  '226.traffic-light',
#  '227.treadmill',
#  '228.triceratops',
#  '229.tricycle',
#  '230.trilobite-101',
#  '231.tripod',
#  '232.t-shirt',
#  '233.tuning-fork',
#  '234.tweezer',
#  '235.umbrella-101',
#  '236.unicorn',
#  '237.vcr',
#  '238.video-projector',
#  '239.washing-machine',
#  '240.watch-101',
#  '241.waterfall',
#  '242.watermelon',
#  '243.welding-mask',
#  '244.wheelbarrow',
#  '245.windmill',
#  '246.wine-bottle',
#  '247.xylophone',
#  '248.yarmulke',
#  '249.yo-yo',
#  '250.zebra',
#  '251.airplanes-101',
#  '252.car-side-101',
#  '253.faces-easy-101',
#  '254.greyhound',
#  '255.tennis-shoes',
#  '256.toad',
#  '257.clutter']

# %% [markdown]
# #### reduce sampling to test functionality

# %%
train_loader.sampler.indices = train_loader.sampler.indices

# %%
len(train_loader)
# Out:
# 766

# %%
val_loader.sampler.indices = val_loader.sampler.indices[:1000]

# %%
next(iter(val_loader))[1]
# Out:
# tensor([205,  45,  95, 184,  76,  75, 209, 256, 160, 253,  20,   3,  33, 243,
#          57, 125,  16, 252,   5, 250, 189,  29, 168, 104, 224,  54, 104,  47,
#         228, 180,  88,  11])

# %% [markdown]
# #### create test network

# %%
model = custom_resnet18(num_classes=257, p=0.5)

# %%
sol = solver(optim_args = {'lr': 0.0001})

# %%
sol.train(model, train_loader, val_loader, num_epochs=40, show_intermediate_steps = 20)
# Out:
# starting training process.
#
# training epoch [1]
# Percent: [###################################] 100% train_loss: 5.454 train_acc: 10.26 Done...
# loss_train_avg: 5.456, train_acc_avg: 10.063
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.407, val_acc_avg: 15.067
#
# training epoch [2]
# Percent: [###################################] 100% train_loss: 5.378 train_acc: 17.95 Done...
# loss_train_avg: 5.383, train_acc_avg: 17.495
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.372, val_acc_avg: 18.920
#
# training epoch [3]
# Percent: [###################################] 100% train_loss: 5.213 train_acc: 33.33 Done...
# loss_train_avg: 5.340, train_acc_avg: 21.942
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.341, val_acc_avg: 22.271
#
# training epoch [4]
# Percent: [###################################] 100% train_loss: 5.331 train_acc: 23.08 Done...
# loss_train_avg: 5.294, train_acc_avg: 26.855
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.293, val_acc_avg: 27.326
#
# training epoch [5]
# Percent: [###################################] 100% train_loss: 5.274 train_acc: 30.77 Done...
# loss_train_avg: 5.235, train_acc_avg: 33.044
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.238, val_acc_avg: 32.780
#
# training epoch [6]
# Percent: [###################################] 100% train_loss: 5.201 train_acc: 35.9 Done...
# loss_train_avg: 5.187, train_acc_avg: 37.957
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.195, val_acc_avg: 37.034
#
# training epoch [7]
# Percent: [###################################] 100% train_loss: 5.147 train_acc: 41.03 Done...
# loss_train_avg: 5.146, train_acc_avg: 42.005
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.157, val_acc_avg: 40.813
#
# training epoch [8]
# Percent: [###################################] 100% train_loss: 5.16 train_acc: 41.03 Done...
# loss_train_avg: 5.107, train_acc_avg: 45.917
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.131, val_acc_avg: 43.304
#
# training epoch [9]
# Percent: [###################################] 100% train_loss: 5.252 train_acc: 30.77 Done...
# loss_train_avg: 5.078, train_acc_avg: 48.852
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.129, val_acc_avg: 44.198
#
# training epoch [10]
# Percent: [###################################] 100% train_loss: 5.12 train_acc: 43.59 Done...
# loss_train_avg: 5.053, train_acc_avg: 51.387
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.120, val_acc_avg: 44.712
#
# training epoch [11]
# Percent: [###################################] 100% train_loss: 5.099 train_acc: 46.15 Done...
# loss_train_avg: 5.029, train_acc_avg: 53.764
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.083, val_acc_avg: 48.067
#
# training epoch [12]
# Percent: [###################################] 100% train_loss: 4.958 train_acc: 61.54 Done...
# loss_train_avg: 5.010, train_acc_avg: 55.546
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.086, val_acc_avg: 47.679
#
# training epoch [13]
# Percent: [###################################] 100% train_loss: 5.125 train_acc: 43.59 Done...
# loss_train_avg: 4.996, train_acc_avg: 56.874
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.063, val_acc_avg: 50.188
#
# training epoch [14]
# Percent: [###################################] 100% train_loss: 4.996 train_acc: 56.41 Done...
# loss_train_avg: 4.980, train_acc_avg: 58.360
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.064, val_acc_avg: 50.285
#
# training epoch [15]
# Percent: [###################################] 100% train_loss: 4.984 train_acc: 58.97 Done...
# loss_train_avg: 4.967, train_acc_avg: 59.700
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.063, val_acc_avg: 49.775
#
# training epoch [16]
# Percent: [###################################] 100% train_loss: 4.945 train_acc: 61.54 Done...
# loss_train_avg: 4.951, train_acc_avg: 61.216
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.053, val_acc_avg: 51.285
#
# training epoch [17]
# Percent: [###################################] 100% train_loss: 5.124 train_acc: 43.59 Done...
# loss_train_avg: 4.940, train_acc_avg: 62.426
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.044, val_acc_avg: 52.081
#
# training epoch [18]
# Percent: [###################################] 100% train_loss: 5.033 train_acc: 53.85 Done...
# loss_train_avg: 4.932, train_acc_avg: 63.032
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.045, val_acc_avg: 51.793
#
# training epoch [19]
# Percent: [###################################] 100% train_loss: 4.992 train_acc: 56.41 Done...
# loss_train_avg: 4.925, train_acc_avg: 63.651
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.029, val_acc_avg: 53.077
#
# training epoch [20]
# Percent: [###################################] 100% train_loss: 4.78 train_acc: 76.92 Done...
# loss_train_avg: 4.918, train_acc_avg: 64.316
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.029, val_acc_avg: 53.318
#
# training epoch [21]
# Percent: [###################################] 100% train_loss: 4.92 train_acc: 64.1 Done...
# loss_train_avg: 4.910, train_acc_avg: 65.168
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.022, val_acc_avg: 54.059
#
# training epoch [22]
# Percent: [###################################] 100% train_loss: 4.851 train_acc: 71.79 Done...
# loss_train_avg: 4.905, train_acc_avg: 65.633
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.019, val_acc_avg: 54.294
#
# training epoch [23]
# Percent: [###################################] 100% train_loss: 4.898 train_acc: 69.23 Done...
# loss_train_avg: 4.898, train_acc_avg: 66.275
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.023, val_acc_avg: 54.119
#
# training epoch [24]
# Percent: [###################################] 100% train_loss: 4.942 train_acc: 61.54 Done...
# loss_train_avg: 4.887, train_acc_avg: 67.548
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.001, val_acc_avg: 55.852
#
# training epoch [25]
# Percent: [###################################] 100% train_loss: 4.733 train_acc: 82.05 Done...
# loss_train_avg: 4.877, train_acc_avg: 68.511
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.995, val_acc_avg: 56.646
#
# training epoch [26]
# Percent: [###################################] 100% train_loss: 4.802 train_acc: 74.36 Done...
# loss_train_avg: 4.873, train_acc_avg: 68.822
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.995, val_acc_avg: 56.771
#
# training epoch [27]
# Percent: [###################################] 100% train_loss: 4.77 train_acc: 79.49 Done...
# loss_train_avg: 4.868, train_acc_avg: 69.288
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.997, val_acc_avg: 56.716
#
# training epoch [28]
# Percent: [###################################] 100% train_loss: 4.825 train_acc: 74.36 Done...
# loss_train_avg: 4.859, train_acc_avg: 70.131
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.977, val_acc_avg: 58.656
#
# training epoch [29]
# Percent: [###################################] 100% train_loss: 4.976 train_acc: 58.97 Done...
# loss_train_avg: 4.856, train_acc_avg: 70.487
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.981, val_acc_avg: 58.095
#
# training epoch [30]
# Percent: [###################################] 100% train_loss: 4.87 train_acc: 69.23 Done...
# loss_train_avg: 4.851, train_acc_avg: 70.979
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.983, val_acc_avg: 58.271
#
# training epoch [31]
# Percent: [###################################] 100% train_loss: 4.963 train_acc: 58.97 Done...
# loss_train_avg: 4.846, train_acc_avg: 71.409
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.985, val_acc_avg: 57.863
#
# training epoch [32]
# Percent: [###################################] 100% train_loss: 4.765 train_acc: 79.49 Done...
# loss_train_avg: 4.839, train_acc_avg: 72.197
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.988, val_acc_avg: 57.194
#
# training epoch [33]
# Percent: [###################################] 100% train_loss: 4.8 train_acc: 76.92 Done...
# loss_train_avg: 4.836, train_acc_avg: 72.394
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.982, val_acc_avg: 58.206
#
# training epoch [34]
# Percent: [###################################] 100% train_loss: 4.852 train_acc: 69.23 Done...
# loss_train_avg: 4.833, train_acc_avg: 72.737
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.982, val_acc_avg: 57.662
#
# training epoch [35]
# Percent: [###################################] 100% train_loss: 4.845 train_acc: 71.79 Done...
# loss_train_avg: 4.826, train_acc_avg: 73.470
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.977, val_acc_avg: 58.328
#
# training epoch [36]
# Percent: [###################################] 100% train_loss: 4.831 train_acc: 71.79 Done...
# loss_train_avg: 4.821, train_acc_avg: 73.939
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.964, val_acc_avg: 59.398
#
# training epoch [37]
# Percent: [###################################] 100% train_loss: 4.765 train_acc: 79.49 Done...
# loss_train_avg: 4.817, train_acc_avg: 74.330
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.971, val_acc_avg: 59.322
#
# training epoch [38]
# Percent: [###################################] 100% train_loss: 4.798 train_acc: 76.92 Done...
# loss_train_avg: 4.814, train_acc_avg: 74.589
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.972, val_acc_avg: 58.867
#
# training epoch [39]
# Percent: [###################################] 100% train_loss: 4.749 train_acc: 82.05 Done...
# loss_train_avg: 4.812, train_acc_avg: 74.839
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.966, val_acc_avg: 59.668
#
# training epoch [40]
# Percent: [###################################] 100% train_loss: 4.918 train_acc: 64.1 Done...
# loss_train_avg: 4.807, train_acc_avg: 75.310
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.963, val_acc_avg: 59.711

# %%
plt.rcParams.update({'font.size': 14})
plot_training_stats(sol)

# %%
path = "./models/upper_baseline/20191201_upper-baseline_40_epochs_BS_64"

# %%
import os
os.makedirs(os.path.dirname(path), exist_ok=True)

# %%
torch.save(model.state_dict(), path)
