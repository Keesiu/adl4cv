# %%
from src.active_learner import active_learner

# %%
al = active_learner(n_initial_samples = 200, n_epochs = [2,2,2], low_certainty_method = 'Random')

# %%
al.do_active_learning()
# Out:
# STARTING THE ACTIVE LEARNING PROCESS
#
# You are using None for the high certainty estimation and Random for the low certainty estimation
# There will be 3 active learning cycles
#
#
# INITIAL TRAINING with 200 samples
#
# starting training process.
#
# training epoch [1]
# Percent: [###################################] 100% train_loss: 5.549 train_acc: 0.0 Done...
# loss_train_avg: 5.549, train_acc_avg: 3.125
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.548, val_acc_avg: 3.125
#
# training epoch [2]
# Percent: [###################################] 100% train_loss: 5.47 train_acc: 25.0 Done...
# loss_train_avg: 5.530, train_acc_avg: 13.839
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.522, val_acc_avg: 3.571
# 1. AL CYCLE
#
# Don't calculate high_certainty_samples
#
# 40 least confident samples have been added to the trainingsset
# ...

# %%
import numpy as np
a = np.asarray([1,2,3,4,5,6])
b = np.asarray([1,2,3,4,5,6])

# %%
np.asarray(list(set(np.append(a,b))))
# Out:
# array([1, 2, 3, 4, 5, 6])
