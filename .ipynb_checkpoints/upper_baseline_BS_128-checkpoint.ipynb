# %% [markdown]
# #### import libraries

# %%
from src import get_dataloader
from src.utils import show_batch
from src.utils import plot_training_stats
from src.neural_network import custom_resnet18
from src.solver import solver
from matplotlib import pyplot as plt
import numpy as np
import torch

# %% [markdown]
# #### get dataloaders

# %%
train_loader, val_loader, test_loader = get_dataloader.main(
    DATA_DIR = "./data/256_ObjectCategories",
    TEST_RATIO = 0.1,
    VAL_RATIO = 0.1,
    RS = 42, # Random seed
    BS = 256, # Batch size
    TOTAL_MEANS = [0.485, 0.456, 0.406], # use [0.5520134568214417, 0.533597469329834, 0.5050241947174072], # for custom total means per RGB-channel
    TOTAL_STDS = [0.229, 0.224, 0.225], # use [0.03332509845495224, 0.03334072232246399, 0.0340290367603302], # total stds per RGB-channel
    RANDOM_AFFINE = 5,
    RESIZE = (224, 224),
    RANDOM_CROP = (160, 160)
)

# %%
train_loader.dataset.classes
# Out:
# ['001.ak47',
#  '002.american-flag',
#  '003.backpack',
#  '004.baseball-bat',
#  '005.baseball-glove',
#  '006.basketball-hoop',
#  '007.bat',
#  '008.bathtub',
#  '009.bear',
#  '010.beer-mug',
#  '011.billiards',
#  '012.binoculars',
#  '013.birdbath',
#  '014.blimp',
#  '015.bonsai-101',
#  '016.boom-box',
#  '017.bowling-ball',
#  '018.bowling-pin',
#  '019.boxing-glove',
#  '020.brain-101',
#  '021.breadmaker',
#  '022.buddha-101',
#  '023.bulldozer',
#  '024.butterfly',
#  '025.cactus',
#  '026.cake',
#  '027.calculator',
#  '028.camel',
#  '029.cannon',
#  '030.canoe',
#  '031.car-tire',
#  '032.cartman',
#  '033.cd',
#  '034.centipede',
#  '035.cereal-box',
#  '036.chandelier-101',
#  '037.chess-board',
#  '038.chimp',
#  '039.chopsticks',
#  '040.cockroach',
#  '041.coffee-mug',
#  '042.coffin',
#  '043.coin',
#  '044.comet',
#  '045.computer-keyboard',
#  '046.computer-monitor',
#  '047.computer-mouse',
#  '048.conch',
#  '049.cormorant',
#  '050.covered-wagon',
#  '051.cowboy-hat',
#  '052.crab-101',
#  '053.desk-globe',
#  '054.diamond-ring',
#  '055.dice',
#  '056.dog',
#  '057.dolphin-101',
#  '058.doorknob',
#  '059.drinking-straw',
#  '060.duck',
#  '061.dumb-bell',
#  '062.eiffel-tower',
#  '063.electric-guitar-101',
#  '064.elephant-101',
#  '065.elk',
#  '066.ewer-101',
#  '067.eyeglasses',
#  '068.fern',
#  '069.fighter-jet',
#  '070.fire-extinguisher',
#  '071.fire-hydrant',
#  '072.fire-truck',
#  '073.fireworks',
#  '074.flashlight',
#  '075.floppy-disk',
#  '076.football-helmet',
#  '077.french-horn',
#  '078.fried-egg',
#  '079.frisbee',
#  '080.frog',
#  '081.frying-pan',
#  '082.galaxy',
#  '083.gas-pump',
#  '084.giraffe',
#  '085.goat',
#  '086.golden-gate-bridge',
#  '087.goldfish',
#  '088.golf-ball',
#  '089.goose',
#  '090.gorilla',
#  '091.grand-piano-101',
#  '092.grapes',
#  '093.grasshopper',
#  '094.guitar-pick',
#  '095.hamburger',
#  '096.hammock',
#  '097.harmonica',
#  '098.harp',
#  '099.harpsichord',
#  '100.hawksbill-101',
#  '101.head-phones',
#  '102.helicopter-101',
#  '103.hibiscus',
#  '104.homer-simpson',
#  '105.horse',
#  '106.horseshoe-crab',
#  '107.hot-air-balloon',
#  '108.hot-dog',
#  '109.hot-tub',
#  '110.hourglass',
#  '111.house-fly',
#  '112.human-skeleton',
#  '113.hummingbird',
#  '114.ibis-101',
#  '115.ice-cream-cone',
#  '116.iguana',
#  '117.ipod',
#  '118.iris',
#  '119.jesus-christ',
#  '120.joy-stick',
#  '121.kangaroo-101',
#  '122.kayak',
#  '123.ketch-101',
#  '124.killer-whale',
#  '125.knife',
#  '126.ladder',
#  '127.laptop-101',
#  '128.lathe',
#  '129.leopards-101',
#  '130.license-plate',
#  '131.lightbulb',
#  '132.light-house',
#  '133.lightning',
#  '134.llama-101',
#  '135.mailbox',
#  '136.mandolin',
#  '137.mars',
#  '138.mattress',
#  '139.megaphone',
#  '140.menorah-101',
#  '141.microscope',
#  '142.microwave',
#  '143.minaret',
#  '144.minotaur',
#  '145.motorbikes-101',
#  '146.mountain-bike',
#  '147.mushroom',
#  '148.mussels',
#  '149.necktie',
#  '150.octopus',
#  '151.ostrich',
#  '152.owl',
#  '153.palm-pilot',
#  '154.palm-tree',
#  '155.paperclip',
#  '156.paper-shredder',
#  '157.pci-card',
#  '158.penguin',
#  '159.people',
#  '160.pez-dispenser',
#  '161.photocopier',
#  '162.picnic-table',
#  '163.playing-card',
#  '164.porcupine',
#  '165.pram',
#  '166.praying-mantis',
#  '167.pyramid',
#  '168.raccoon',
#  '169.radio-telescope',
#  '170.rainbow',
#  '171.refrigerator',
#  '172.revolver-101',
#  '173.rifle',
#  '174.rotary-phone',
#  '175.roulette-wheel',
#  '176.saddle',
#  '177.saturn',
#  '178.school-bus',
#  '179.scorpion-101',
#  '180.screwdriver',
#  '181.segway',
#  '182.self-propelled-lawn-mower',
#  '183.sextant',
#  '184.sheet-music',
#  '185.skateboard',
#  '186.skunk',
#  '187.skyscraper',
#  '188.smokestack',
#  '189.snail',
#  '190.snake',
#  '191.sneaker',
#  '192.snowmobile',
#  '193.soccer-ball',
#  '194.socks',
#  '195.soda-can',
#  '196.spaghetti',
#  '197.speed-boat',
#  '198.spider',
#  '199.spoon',
#  '200.stained-glass',
#  '201.starfish-101',
#  '202.steering-wheel',
#  '203.stirrups',
#  '204.sunflower-101',
#  '205.superman',
#  '206.sushi',
#  '207.swan',
#  '208.swiss-army-knife',
#  '209.sword',
#  '210.syringe',
#  '211.tambourine',
#  '212.teapot',
#  '213.teddy-bear',
#  '214.teepee',
#  '215.telephone-box',
#  '216.tennis-ball',
#  '217.tennis-court',
#  '218.tennis-racket',
#  '219.theodolite',
#  '220.toaster',
#  '221.tomato',
#  '222.tombstone',
#  '223.top-hat',
#  '224.touring-bike',
#  '225.tower-pisa',
#  '226.traffic-light',
#  '227.treadmill',
#  '228.triceratops',
#  '229.tricycle',
#  '230.trilobite-101',
#  '231.tripod',
#  '232.t-shirt',
#  '233.tuning-fork',
#  '234.tweezer',
#  '235.umbrella-101',
#  '236.unicorn',
#  '237.vcr',
#  '238.video-projector',
#  '239.washing-machine',
#  '240.watch-101',
#  '241.waterfall',
#  '242.watermelon',
#  '243.welding-mask',
#  '244.wheelbarrow',
#  '245.windmill',
#  '246.wine-bottle',
#  '247.xylophone',
#  '248.yarmulke',
#  '249.yo-yo',
#  '250.zebra',
#  '251.airplanes-101',
#  '252.car-side-101',
#  '253.faces-easy-101',
#  '254.greyhound',
#  '255.tennis-shoes',
#  '256.toad',
#  '257.clutter']

# %% [markdown]
# #### reduce sampling to test functionality

# %%
train_loader.sampler.indices = train_loader.sampler.indices

# %%
len(train_loader)
# Out:
# 766

# %%
val_loader.sampler.indices = val_loader.sampler.indices[:1000]

# %%
next(iter(val_loader))[1]
# Out:
# tensor([205,  45,  95, 184,  76,  75, 209, 256, 160, 253,  20,   3,  33, 243,
#          57, 125,  16, 252,   5, 250, 189,  29, 168, 104, 224,  54, 104,  47,
#         228, 180,  88,  11])

# %% [markdown]
# #### create test network

# %%
model = custom_resnet18(num_classes=257, p=0.5)

# %%
sol = solver(optim_args = {'lr': 0.0001})

# %%
sol.train(model, train_loader, val_loader, num_epochs=40, show_intermediate_steps = 20)
# Out:
# starting training process.
#
# training epoch [1]
# Percent: [###################################] 100% train_loss: 5.479 train_acc: 7.19 Done...
# loss_train_avg: 5.494, train_acc_avg: 6.597
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.500, val_acc_avg: 9.371
#
# training epoch [2]
# Percent: [###################################] 100% train_loss: 5.422 train_acc: 13.17 Done...
# loss_train_avg: 5.434, train_acc_avg: 12.157
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.425, val_acc_avg: 13.235
#
# training epoch [3]
# Percent: [###################################] 100% train_loss: 5.397 train_acc: 16.77 Done...
# loss_train_avg: 5.391, train_acc_avg: 16.695
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.387, val_acc_avg: 17.050
#
# training epoch [4]
# Percent: [###################################] 100% train_loss: 5.411 train_acc: 14.37 Done...
# loss_train_avg: 5.356, train_acc_avg: 20.295
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.347, val_acc_avg: 21.491
#
# training epoch [5]
# Percent: [###################################] 100% train_loss: 5.258 train_acc: 30.54 Done...
# loss_train_avg: 5.325, train_acc_avg: 23.467
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.325, val_acc_avg: 23.851
#
# training epoch [6]
# Percent: [###################################] 100% train_loss: 5.274 train_acc: 29.94 Done...
# loss_train_avg: 5.285, train_acc_avg: 27.949
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.277, val_acc_avg: 29.101
#
# training epoch [7]
# Percent: [###################################] 100% train_loss: 5.234 train_acc: 33.53 Done...
# loss_train_avg: 5.238, train_acc_avg: 32.604
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.246, val_acc_avg: 32.760
#
# training epoch [8]
# Percent: [###################################] 100% train_loss: 5.223 train_acc: 36.53 Done...
# loss_train_avg: 5.190, train_acc_avg: 37.840
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.207, val_acc_avg: 36.375
#
# training epoch [9]
# Percent: [###################################] 100% train_loss: 5.139 train_acc: 43.71 Done...
# loss_train_avg: 5.147, train_acc_avg: 42.212
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.182, val_acc_avg: 38.621
#
# training epoch [10]
# Percent: [###################################] 100% train_loss: 5.099 train_acc: 47.31 Done...
# loss_train_avg: 5.103, train_acc_avg: 46.631
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.142, val_acc_avg: 43.137
#
# training epoch [11]
# Percent: [###################################] 100% train_loss: 5.057 train_acc: 50.9 Done...
# loss_train_avg: 5.068, train_acc_avg: 50.184
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.120, val_acc_avg: 45.155
#
# training epoch [12]
# Percent: [###################################] 100% train_loss: 5.015 train_acc: 57.49 Done...
# loss_train_avg: 5.035, train_acc_avg: 53.496
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.105, val_acc_avg: 47.188
#
# training epoch [13]
# Percent: [###################################] 100% train_loss: 4.982 train_acc: 58.08 Done...
# loss_train_avg: 5.008, train_acc_avg: 56.245
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.076, val_acc_avg: 49.594
#
# training epoch [14]
# Percent: [###################################] 100% train_loss: 4.984 train_acc: 58.68 Done...
# loss_train_avg: 4.983, train_acc_avg: 58.570
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.066, val_acc_avg: 50.516
#
# training epoch [15]
# Percent: [###################################] 100% train_loss: 4.967 train_acc: 59.28 Done...
# loss_train_avg: 4.963, train_acc_avg: 60.489
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.060, val_acc_avg: 51.146
#
# training epoch [16]
# Percent: [###################################] 100% train_loss: 5.029 train_acc: 52.69 Done...
# loss_train_avg: 4.946, train_acc_avg: 62.044
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.053, val_acc_avg: 51.940
#
# training epoch [17]
# Percent: [###################################] 100% train_loss: 4.951 train_acc: 62.28 Done...
# loss_train_avg: 4.935, train_acc_avg: 63.222
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.040, val_acc_avg: 52.865
#
# training epoch [18]
# Percent: [###################################] 100% train_loss: 4.983 train_acc: 58.08 Done...
# loss_train_avg: 4.922, train_acc_avg: 64.452
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.033, val_acc_avg: 53.475
#
# training epoch [19]
# Percent: [###################################] 100% train_loss: 4.946 train_acc: 61.68 Done...
# loss_train_avg: 4.909, train_acc_avg: 65.580
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.017, val_acc_avg: 55.628
#
# training epoch [20]
# Percent: [###################################] 100% train_loss: 4.934 train_acc: 63.47 Done...
# loss_train_avg: 4.900, train_acc_avg: 66.449
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.022, val_acc_avg: 54.726
#
# training epoch [21]
# Percent: [###################################] 100% train_loss: 4.9 train_acc: 65.87 Done...
# loss_train_avg: 4.887, train_acc_avg: 67.784
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.007, val_acc_avg: 56.328
#
# training epoch [22]
# Percent: [###################################] 100% train_loss: 4.88 train_acc: 67.66 Done...
# loss_train_avg: 4.876, train_acc_avg: 68.824
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.010, val_acc_avg: 56.350
#
# training epoch [23]
# Percent: [###################################] 100% train_loss: 4.882 train_acc: 68.26 Done...
# loss_train_avg: 4.864, train_acc_avg: 70.120
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.005, val_acc_avg: 56.495
#
# training epoch [24]
# Percent: [###################################] 100% train_loss: 4.851 train_acc: 72.46 Done...
# loss_train_avg: 4.859, train_acc_avg: 70.461
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.995, val_acc_avg: 57.320
#
# training epoch [25]
# Percent: [###################################] 100% train_loss: 4.822 train_acc: 74.25 Done...
# loss_train_avg: 4.849, train_acc_avg: 71.529
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.983, val_acc_avg: 58.665
#
# training epoch [26]
# Percent: [###################################] 100% train_loss: 4.813 train_acc: 74.85 Done...
# loss_train_avg: 4.841, train_acc_avg: 72.227
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.983, val_acc_avg: 58.224
#
# training epoch [27]
# Percent: [###################################] 100% train_loss: 4.83 train_acc: 73.05 Done...
# loss_train_avg: 4.832, train_acc_avg: 73.014
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.974, val_acc_avg: 59.286
#
# training epoch [28]
# Percent: [###################################] 100% train_loss: 4.882 train_acc: 67.66 Done...
# loss_train_avg: 4.827, train_acc_avg: 73.552
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.964, val_acc_avg: 60.437
#
# training epoch [29]
# Percent: [###################################] 100% train_loss: 4.873 train_acc: 70.06 Done...
# loss_train_avg: 4.821, train_acc_avg: 74.118
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.973, val_acc_avg: 59.737
#
# training epoch [30]
# Percent: [###################################] 100% train_loss: 4.829 train_acc: 72.46 Done...
# loss_train_avg: 4.815, train_acc_avg: 74.619
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.969, val_acc_avg: 59.952
#
# training epoch [31]
# Percent: [###################################] 100% train_loss: 4.845 train_acc: 72.46 Done...
# loss_train_avg: 4.812, train_acc_avg: 74.941
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.971, val_acc_avg: 59.475
#
# training epoch [32]
# Percent: [###################################] 100% train_loss: 4.791 train_acc: 76.65 Done...
# loss_train_avg: 4.806, train_acc_avg: 75.546
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.972, val_acc_avg: 59.513
#
# training epoch [33]
# Percent: [###################################] 100% train_loss: 4.774 train_acc: 79.04 Done...
# loss_train_avg: 4.802, train_acc_avg: 75.905
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.966, val_acc_avg: 59.846
#
# training epoch [34]
# Percent: [###################################] 100% train_loss: 4.821 train_acc: 74.25 Done...
# loss_train_avg: 4.798, train_acc_avg: 76.225
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.962, val_acc_avg: 60.461
#
# training epoch [35]
# Percent: [###################################] 100% train_loss: 4.784 train_acc: 77.25 Done...
# loss_train_avg: 4.796, train_acc_avg: 76.509
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.945, val_acc_avg: 62.670
#
# training epoch [36]
# Percent: [###################################] 100% train_loss: 4.796 train_acc: 76.05 Done...
# loss_train_avg: 4.795, train_acc_avg: 76.529
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.957, val_acc_avg: 60.886
#
# training epoch [37]
# Percent: [###################################] 100% train_loss: 4.79 train_acc: 76.65 Done...
# loss_train_avg: 4.791, train_acc_avg: 76.950
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.959, val_acc_avg: 60.666
#
# training epoch [38]
# Percent: [###################################] 100% train_loss: 4.82 train_acc: 74.25 Done...
# loss_train_avg: 4.788, train_acc_avg: 77.246
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.958, val_acc_avg: 60.706
#
# training epoch [39]
# Percent: [###################################] 100% train_loss: 4.778 train_acc: 79.04 Done...
# loss_train_avg: 4.787, train_acc_avg: 77.345
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.961, val_acc_avg: 60.720
#
# training epoch [40]
# Percent: [###################################] 100% train_loss: 4.777 train_acc: 79.04 Done...
# loss_train_avg: 4.784, train_acc_avg: 77.573
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 4.962, val_acc_avg: 60.771

# %%
plt.rcParams.update({'font.size': 14})
plot_training_stats(sol)

# %%
path = "./models/upper_baseline/20191128_upper-baseline_40_epochs_BS_256_runtime_3h"

# %%
import os
os.makedirs(os.path.dirname(path), exist_ok=True)

# %%
torch.save(model.state_dict(), path)
