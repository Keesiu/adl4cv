# %%
from src.active_learner import active_learner

# %%
al = active_learner(n_initial_samples = 2427, n_epochs=[25], low_certainty_threshold = 1000, low_certainty_method = 'Softmax',
                   softmax_uncertainty_method ='entropy')

# %%
al.do_active_learning()
# Out:
# STARTING THE ACTIVE LEARNING PROCESS
#
# You are using None for the high certainty estimation and Softmax for the low certainty estimation
# There will be 1 active learning cycles
#
#
# INITIAL TRAINING with 24 samples (12.0% of total Dataset labeled)
#
# starting training process.
#
# training epoch [1]
# Percent: [###################################] 100% train_loss: 5.549 train_acc: 0.0 Done...
# loss_train_avg: 5.549, train_acc_avg: 0.000
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.549, val_acc_avg: 0.000
# Start testing model
# Percent: [###################################] 100% Done...
# Model scored 0.0% on Validation Set
# 1. AL CYCLE
#
# Starting to predict for Softmax uncertainty measurement using least_confidence
# Percent: [###################################] 100% Done...
#
# 176 least confident samples have been added to the trainingsset
# 0 most confident samples have been added to the trainingsset
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
a = np.asarray([[14,1],[3,2],[4,3],[12,4]])

# %%
df = pd.DataFrame(a, columns =['Hallo', 'Peter'])

# %%
df.sort_values(by=['Hallo'])
# Out:
#    Hallo  Peter
# 1      3      2
# 2      4      3
# 3     12      4
# 0     14      1
