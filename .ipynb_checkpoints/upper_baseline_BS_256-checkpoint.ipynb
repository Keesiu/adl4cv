# %% [markdown]
# #### import libraries

# %%
from src import get_dataloader
from src.utils import show_batch
from src.utils import plot_training_stats
from src.neural_network import custom_resnet18
from src.solver import solver
from matplotlib import pyplot as plt
import numpy as np
import torch

# %% [markdown]
# #### get dataloaders

# %%
train_loader, val_loader, test_loader = get_dataloader.main(
    DATA_DIR = ".\\data\\256_ObjectCategories",
    TEST_RATIO = 0.1,
    VAL_RATIO = 0.1,
    RS = 42, # Random seed
    BS = 32, # Batch size
    TOTAL_MEANS = [0.5520134568214417, 0.533597469329834, 0.5050241947174072], # total means per RGB-channel
    TOTAL_STDS = [0.03332509845495224, 0.03334072232246399, 0.0340290367603302], # total stds per RGB-channel
    RANDOM_AFFINE = 5,
    RESIZE = (224, 224),
    RANDOM_CROP = (160, 160)
)

# %%
#train_loader.dataset.classes

# %%
show_batch(train_loader)

# %% [markdown]
# #### reduce sampling to 4 samples

# %%
train_loader.sampler.indices = train_loader.sampler.indices[:]

# %%
len(train_loader)
# Out:
# 766

# %%
val_loader.sampler.indices = val_loader.sampler.indices[:]

# %%
next(iter(val_loader))[1]
# Out:
# tensor([167,  22, 185,  66, 191, 102, 188,  40, 228, 169,  50, 237, 244,  19,
#         151, 189,  46, 242,  88,  30, 241, 231,  30,  21,  47, 256, 202, 201,
#           2,  64, 232, 107])

# %% [markdown]
# #### create test network

# %%
model = custom_resnet18(num_classes=257, p=0.5)

# %%
sol = solver(optim_args = {'lr': 0.0001})

# %%
sol.train(model, train_loader, val_loader, num_epochs=40, show_intermediate_steps = 100)
# Out:
# START TRAIN.
#
# START Training Epoch [1]
#
# [100 / 766] loss_train: 4.459, train_acc: 0.188
# [200 / 766] loss_train: 4.146, train_acc: 0.281
# [300 / 766] loss_train: 3.737, train_acc: 0.219
# [400 / 766] loss_train: 3.769, train_acc: 0.094
# [500 / 766] loss_train: 2.666, train_acc: 0.406
# [600 / 766] loss_train: 1.972, train_acc: 0.656
# [700 / 766] loss_train: 2.300, train_acc: 0.469
# [766 / 766] loss_train: 2.130, train_acc: 0.571
#
# FINISHED Epoch [1] loss_train_avg: 3.360, train_acc_avg: 33.299
# VALIDATED Epoch [1] loss_val_avg: 1.919, val_acc_avg: 57.031
#
#
# START Training Epoch [2]
#
# [100 / 766] loss_train: 1.923, train_acc: 0.500
# [200 / 766] loss_train: 1.909, train_acc: 0.531
# [300 / 766] loss_train: 1.662, train_acc: 0.594
# [400 / 766] loss_train: 1.338, train_acc: 0.719
# [500 / 766] loss_train: 1.513, train_acc: 0.656
# [600 / 766] loss_train: 1.619, train_acc: 0.562
# [700 / 766] loss_train: 1.430, train_acc: 0.594
# ...

# %%
plt.rcParams.update({'font.size': 14})
plot_training_stats(sol)

# %%
torch.save(model.state_dict(), ".\\models\\upper_baseline\\ub_valacc_73_350_061119_fulldata_res18_bs32_lr10-4_ep10")
