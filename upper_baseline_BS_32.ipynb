# %% [markdown]
# #### import libraries

# %%
from src import get_dataloader
from src.utils import show_batch
from src.utils import plot_training_stats
from src.neural_network import custom_resnet18
from src.solver import solver
from matplotlib import pyplot as plt
import numpy as np
import torch

# %% [markdown]
# #### get dataloaders

# %%
train_loader, val_loader, test_loader = get_dataloader.main(
    DATA_DIR = "./data/256_ObjectCategories",
    TEST_RATIO = 0.1,
    VAL_RATIO = 0.1,
    RS = 42, # Random seed
    BS = 32, # Batch size
    TOTAL_MEANS = [0.485, 0.456, 0.406], # use [0.5520134568214417, 0.533597469329834, 0.5050241947174072], # for custom total means per RGB-channel
    TOTAL_STDS = [0.229, 0.224, 0.225], # use [0.03332509845495224, 0.03334072232246399, 0.0340290367603302], # total stds per RGB-channel
    RANDOM_AFFINE = 5,
    RESIZE = (224, 224),
    RANDOM_CROP = (160, 160)
)

# %%
train_loader.dataset.classes
# Out:
# ['001.ak47',
#  '002.american-flag',
#  '003.backpack',
#  '004.baseball-bat',
#  '005.baseball-glove',
#  '006.basketball-hoop',
#  '007.bat',
#  '008.bathtub',
#  '009.bear',
#  '010.beer-mug',
#  '011.billiards',
#  '012.binoculars',
#  '013.birdbath',
#  '014.blimp',
#  '015.bonsai-101',
#  '016.boom-box',
#  '017.bowling-ball',
#  '018.bowling-pin',
#  '019.boxing-glove',
#  '020.brain-101',
#  '021.breadmaker',
#  '022.buddha-101',
#  '023.bulldozer',
#  '024.butterfly',
#  '025.cactus',
#  '026.cake',
#  '027.calculator',
#  '028.camel',
#  '029.cannon',
#  '030.canoe',
#  '031.car-tire',
#  '032.cartman',
#  '033.cd',
#  '034.centipede',
#  '035.cereal-box',
#  '036.chandelier-101',
#  '037.chess-board',
#  '038.chimp',
#  '039.chopsticks',
#  '040.cockroach',
#  '041.coffee-mug',
#  '042.coffin',
#  '043.coin',
#  '044.comet',
#  '045.computer-keyboard',
#  '046.computer-monitor',
#  '047.computer-mouse',
#  '048.conch',
#  '049.cormorant',
#  '050.covered-wagon',
#  '051.cowboy-hat',
#  '052.crab-101',
#  '053.desk-globe',
#  '054.diamond-ring',
#  '055.dice',
#  '056.dog',
#  '057.dolphin-101',
#  '058.doorknob',
#  '059.drinking-straw',
#  '060.duck',
#  '061.dumb-bell',
#  '062.eiffel-tower',
#  '063.electric-guitar-101',
#  '064.elephant-101',
#  '065.elk',
#  '066.ewer-101',
#  '067.eyeglasses',
#  '068.fern',
#  '069.fighter-jet',
#  '070.fire-extinguisher',
#  '071.fire-hydrant',
#  '072.fire-truck',
#  '073.fireworks',
#  '074.flashlight',
#  '075.floppy-disk',
#  '076.football-helmet',
#  '077.french-horn',
#  '078.fried-egg',
#  '079.frisbee',
#  '080.frog',
#  '081.frying-pan',
#  '082.galaxy',
#  '083.gas-pump',
#  '084.giraffe',
#  '085.goat',
#  '086.golden-gate-bridge',
#  '087.goldfish',
#  '088.golf-ball',
#  '089.goose',
#  '090.gorilla',
#  '091.grand-piano-101',
#  '092.grapes',
#  '093.grasshopper',
#  '094.guitar-pick',
#  '095.hamburger',
#  '096.hammock',
#  '097.harmonica',
#  '098.harp',
#  '099.harpsichord',
#  '100.hawksbill-101',
#  '101.head-phones',
#  '102.helicopter-101',
#  '103.hibiscus',
#  '104.homer-simpson',
#  '105.horse',
#  '106.horseshoe-crab',
#  '107.hot-air-balloon',
#  '108.hot-dog',
#  '109.hot-tub',
#  '110.hourglass',
#  '111.house-fly',
#  '112.human-skeleton',
#  '113.hummingbird',
#  '114.ibis-101',
#  '115.ice-cream-cone',
#  '116.iguana',
#  '117.ipod',
#  '118.iris',
#  '119.jesus-christ',
#  '120.joy-stick',
#  '121.kangaroo-101',
#  '122.kayak',
#  '123.ketch-101',
#  '124.killer-whale',
#  '125.knife',
#  '126.ladder',
#  '127.laptop-101',
#  '128.lathe',
#  '129.leopards-101',
#  '130.license-plate',
#  '131.lightbulb',
#  '132.light-house',
#  '133.lightning',
#  '134.llama-101',
#  '135.mailbox',
#  '136.mandolin',
#  '137.mars',
#  '138.mattress',
#  '139.megaphone',
#  '140.menorah-101',
#  '141.microscope',
#  '142.microwave',
#  '143.minaret',
#  '144.minotaur',
#  '145.motorbikes-101',
#  '146.mountain-bike',
#  '147.mushroom',
#  '148.mussels',
#  '149.necktie',
#  '150.octopus',
#  '151.ostrich',
#  '152.owl',
#  '153.palm-pilot',
#  '154.palm-tree',
#  '155.paperclip',
#  '156.paper-shredder',
#  '157.pci-card',
#  '158.penguin',
#  '159.people',
#  '160.pez-dispenser',
#  '161.photocopier',
#  '162.picnic-table',
#  '163.playing-card',
#  '164.porcupine',
#  '165.pram',
#  '166.praying-mantis',
#  '167.pyramid',
#  '168.raccoon',
#  '169.radio-telescope',
#  '170.rainbow',
#  '171.refrigerator',
#  '172.revolver-101',
#  '173.rifle',
#  '174.rotary-phone',
#  '175.roulette-wheel',
#  '176.saddle',
#  '177.saturn',
#  '178.school-bus',
#  '179.scorpion-101',
#  '180.screwdriver',
#  '181.segway',
#  '182.self-propelled-lawn-mower',
#  '183.sextant',
#  '184.sheet-music',
#  '185.skateboard',
#  '186.skunk',
#  '187.skyscraper',
#  '188.smokestack',
#  '189.snail',
#  '190.snake',
#  '191.sneaker',
#  '192.snowmobile',
#  '193.soccer-ball',
#  '194.socks',
#  '195.soda-can',
#  '196.spaghetti',
#  '197.speed-boat',
#  '198.spider',
#  '199.spoon',
#  '200.stained-glass',
#  '201.starfish-101',
#  '202.steering-wheel',
#  '203.stirrups',
#  '204.sunflower-101',
#  '205.superman',
#  '206.sushi',
#  '207.swan',
#  '208.swiss-army-knife',
#  '209.sword',
#  '210.syringe',
#  '211.tambourine',
#  '212.teapot',
#  '213.teddy-bear',
#  '214.teepee',
#  '215.telephone-box',
#  '216.tennis-ball',
#  '217.tennis-court',
#  '218.tennis-racket',
#  '219.theodolite',
#  '220.toaster',
#  '221.tomato',
#  '222.tombstone',
#  '223.top-hat',
#  '224.touring-bike',
#  '225.tower-pisa',
#  '226.traffic-light',
#  '227.treadmill',
#  '228.triceratops',
#  '229.tricycle',
#  '230.trilobite-101',
#  '231.tripod',
#  '232.t-shirt',
#  '233.tuning-fork',
#  '234.tweezer',
#  '235.umbrella-101',
#  '236.unicorn',
#  '237.vcr',
#  '238.video-projector',
#  '239.washing-machine',
#  '240.watch-101',
#  '241.waterfall',
#  '242.watermelon',
#  '243.welding-mask',
#  '244.wheelbarrow',
#  '245.windmill',
#  '246.wine-bottle',
#  '247.xylophone',
#  '248.yarmulke',
#  '249.yo-yo',
#  '250.zebra',
#  '251.airplanes-101',
#  '252.car-side-101',
#  '253.faces-easy-101',
#  '254.greyhound',
#  '255.tennis-shoes',
#  '256.toad',
#  '257.clutter']

# %% [markdown]
# #### reduce sampling to test functionality

# %%
train_loader.sampler.indices = train_loader.sampler.indices

# %%
len(train_loader)
# Out:
# 766

# %%
val_loader.sampler.indices = val_loader.sampler.indices[:1000]

# %%
next(iter(val_loader))[1]
# Out:
# tensor([205,  45,  95, 184,  76,  75, 209, 256, 160, 253,  20,   3,  33, 243,
#          57, 125,  16, 252,   5, 250, 189,  29, 168, 104, 224,  54, 104,  47,
#         228, 180,  88,  11])

# %% [markdown]
# #### create test network

# %%
model = custom_resnet18(num_classes=257, p=0.5)

# %%
sol = solver(optim_args = {'lr': 0.0001})

# %%
# %%time
sol.train(model, train_loader, val_loader, num_epochs=40, show_intermediate_steps = 20)
# Out:
# starting training process.
#
# training epoch [1]
# Percent: [###################################] 100% train_loss: 5.554 train_acc: 0.0 Done...
# loss_train_avg: 5.446, train_acc_avg: 11.027
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.432, val_acc_avg: 12.604
#
# training epoch [2]
# Percent: [###################################] 100% train_loss: 5.412 train_acc: 14.29 Done...
# loss_train_avg: 5.402, train_acc_avg: 15.464
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.405, val_acc_avg: 15.391
#
# training epoch [3]
# Percent: [###################################] 100% train_loss: 5.336 train_acc: 28.57 Done...
# loss_train_avg: 5.374, train_acc_avg: 18.408
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.371, val_acc_avg: 18.613
#
# training epoch [4]
# Percent: [###################################] 100% train_loss: 5.555 train_acc: 0.0 Done...
# loss_train_avg: 5.343, train_acc_avg: 21.630
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.354, val_acc_avg: 20.247
#
# training epoch [5]
# Percent: [###################################] 100% train_loss: 5.284 train_acc: 28.57 Done...
# loss_train_avg: 5.302, train_acc_avg: 25.821
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.289, val_acc_avg: 27.305
#
# training epoch [6]
# Percent: [###################################] 100% train_loss: 4.882 train_acc: 85.71 Done...
# loss_train_avg: 5.260, train_acc_avg: 30.203
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.259, val_acc_avg: 30.326
#
# training epoch [7]
# Percent: [###################################] 100% train_loss: 5.413 train_acc: 14.29 Done...
# loss_train_avg: 5.226, train_acc_avg: 33.712
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.233, val_acc_avg: 32.917
#
# training epoch [8]
# Percent: [###################################] 100% train_loss: 5.093 train_acc: 42.86 Done...
# loss_train_avg: 5.191, train_acc_avg: 37.160
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.205, val_acc_avg: 36.055
#
# training epoch [9]
# Percent: [###################################] 100% train_loss: 5.181 train_acc: 42.86 Done...
# loss_train_avg: 5.166, train_acc_avg: 39.775
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.170, val_acc_avg: 39.056
#
# training epoch [10]
# Percent: [###################################] 100% train_loss: 5.134 train_acc: 42.86 Done...
# loss_train_avg: 5.137, train_acc_avg: 42.594
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.160, val_acc_avg: 40.286
#
# training epoch [11]
# Percent: [###################################] 100% train_loss: 5.125 train_acc: 42.86 Done...
# loss_train_avg: 5.117, train_acc_avg: 44.585
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.146, val_acc_avg: 41.471
#
# training epoch [12]
# Percent: [###################################] 100% train_loss: 4.963 train_acc: 57.14 Done...
# loss_train_avg: 5.095, train_acc_avg: 46.737
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.132, val_acc_avg: 43.027
#
# training epoch [13]
# Percent: [###################################] 100% train_loss: 5.141 train_acc: 42.86 Done...
# loss_train_avg: 5.079, train_acc_avg: 48.314
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.112, val_acc_avg: 45.208
#
# training epoch [14]
# Percent: [###################################] 100% train_loss: 5.067 train_acc: 42.86 Done...
# loss_train_avg: 5.064, train_acc_avg: 49.836
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.112, val_acc_avg: 45.137
#
# training epoch [15]
# Percent: [###################################] 100% train_loss: 4.932 train_acc: 71.43 Done...
# loss_train_avg: 5.050, train_acc_avg: 51.219
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.107, val_acc_avg: 45.482
#
# training epoch [16]
# Percent: [###################################] 100% train_loss: 5.131 train_acc: 42.86 Done...
# loss_train_avg: 5.037, train_acc_avg: 52.463
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.093, val_acc_avg: 46.986
#
# training epoch [17]
# Percent: [###################################] 100% train_loss: 5.127 train_acc: 42.86 Done...
# loss_train_avg: 5.026, train_acc_avg: 53.569
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.084, val_acc_avg: 47.533
#
# training epoch [18]
# Percent: [###################################] 100% train_loss: 4.901 train_acc: 71.43 Done...
# loss_train_avg: 5.020, train_acc_avg: 54.055
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.080, val_acc_avg: 48.477
#
# training epoch [19]
# Percent: [###################################] 100% train_loss: 4.842 train_acc: 71.43 Done...
# loss_train_avg: 5.010, train_acc_avg: 55.185
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.093, val_acc_avg: 46.901
#
# training epoch [20]
# Percent: [###################################] 100% train_loss: 4.984 train_acc: 57.14 Done...
# loss_train_avg: 5.003, train_acc_avg: 55.872
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.084, val_acc_avg: 47.454
#
# training epoch [21]
# Percent: [###################################] 100% train_loss: 5.267 train_acc: 28.57 Done...
# loss_train_avg: 4.996, train_acc_avg: 56.536
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.062, val_acc_avg: 49.766
#
# training epoch [22]
# Percent: [###################################] 100% train_loss: 5.421 train_acc: 14.29 Done...
# loss_train_avg: 4.988, train_acc_avg: 57.289
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.058, val_acc_avg: 50.169
#
# training epoch [23]
# Percent: [###################################] 100% train_loss: 5.085 train_acc: 42.86 Done...
# loss_train_avg: 4.981, train_acc_avg: 57.917
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.059, val_acc_avg: 50.137
#
# training epoch [24]
# Percent: [###################################] 100% train_loss: 4.984 train_acc: 57.14 Done...
# loss_train_avg: 4.974, train_acc_avg: 58.670
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.062, val_acc_avg: 49.603
#
# training epoch [25]
# Percent: [###################################] 100% train_loss: 4.739 train_acc: 85.71 Done...
# loss_train_avg: 4.971, train_acc_avg: 58.908
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.054, val_acc_avg: 50.514
#
# training epoch [26]
# Percent: [###################################] 100% train_loss: 4.986 train_acc: 57.14 Done...
# loss_train_avg: 4.969, train_acc_avg: 59.082
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.041, val_acc_avg: 52.057
#
# training epoch [27]
# Percent: [###################################] 100% train_loss: 4.945 train_acc: 71.43 Done...
# loss_train_avg: 4.962, train_acc_avg: 59.913
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.045, val_acc_avg: 51.458
#
# training epoch [28]
# Percent: [###################################] 100% train_loss: 5.291 train_acc: 28.57 Done...
# loss_train_avg: 4.958, train_acc_avg: 60.163
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.044, val_acc_avg: 51.641
#
# training epoch [29]
# Percent: [###################################] 100% train_loss: 5.31 train_acc: 14.29 Done...
# loss_train_avg: 4.956, train_acc_avg: 60.414
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.048, val_acc_avg: 51.185
#
# training epoch [30]
# Percent: [###################################] 100% train_loss: 5.139 train_acc: 42.86 Done...
# loss_train_avg: 4.948, train_acc_avg: 61.193
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.034, val_acc_avg: 52.526
#
# training epoch [31]
# Percent: [###################################] 100% train_loss: 5.261 train_acc: 28.57 Done...
# loss_train_avg: 4.943, train_acc_avg: 61.570
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.042, val_acc_avg: 52.051
#
# training epoch [32]
# Percent: [###################################] 100% train_loss: 4.984 train_acc: 57.14 Done...
# loss_train_avg: 4.942, train_acc_avg: 61.738
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.031, val_acc_avg: 53.021
#
# training epoch [33]
# Percent: [###################################] 100% train_loss: 4.854 train_acc: 71.43 Done...
# loss_train_avg: 4.935, train_acc_avg: 62.459
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.044, val_acc_avg: 51.471
#
# training epoch [34]
# Percent: [###################################] 100% train_loss: 4.924 train_acc: 57.14 Done...
# loss_train_avg: 4.931, train_acc_avg: 62.811
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.040, val_acc_avg: 52.155
#
# training epoch [35]
# Percent: [###################################] 100% train_loss: 5.093 train_acc: 42.86 Done...
# loss_train_avg: 4.928, train_acc_avg: 63.062
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.023, val_acc_avg: 53.743
#
# training epoch [36]
# Percent: [###################################] 100% train_loss: 5.037 train_acc: 57.14 Done...
# loss_train_avg: 4.927, train_acc_avg: 63.121
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.029, val_acc_avg: 53.145
#
# training epoch [37]
# Percent: [###################################] 100% train_loss: 5.047 train_acc: 57.14 Done...
# loss_train_avg: 4.923, train_acc_avg: 63.623
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.035, val_acc_avg: 52.435
#
# training epoch [38]
# Percent: [###################################] 100% train_loss: 5.209 train_acc: 28.57 Done...
# loss_train_avg: 4.922, train_acc_avg: 63.631
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.016, val_acc_avg: 54.102
#
# training epoch [39]
# Percent: [###################################] 100% train_loss: 5.378 train_acc: 14.29 Done...
# loss_train_avg: 4.920, train_acc_avg: 63.820
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.051, val_acc_avg: 50.723
#
# training epoch [40]
# Percent: [###################################] 100% train_loss: 4.997 train_acc: 57.14 Done...
# loss_train_avg: 4.917, train_acc_avg: 64.194
# starting validation process
# Percent: [###################################] 100% Done...
# loss_val_avg: 5.040, val_acc_avg: 51.745
# CPU times: user 9h 3min 42s, sys: 33min 45s, total: 9h 37min 27s
# Wall time: 2h 24min 55s

# %%
plt.rcParams.update({'font.size': 14})
plot_training_stats(sol)

# %%
path = "./models/upper_baseline/20191201_upper-baseline_40_epochs_BS_32_runtime_3h"

# %%
import os
os.makedirs(os.path.dirname(path), exist_ok=True)

# %%
torch.save(model.state_dict(), path)
